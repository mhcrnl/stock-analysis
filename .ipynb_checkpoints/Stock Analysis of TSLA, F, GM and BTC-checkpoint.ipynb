# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas_datareader.data as web
import datetime

# %%
start_date = datetime.datetime(2012,1,1)
end_date = datetime.datetime(2020,7,7)

# %%
tesla = web.DataReader('TSLA', 'yahoo', start_date, end_date)
tesla.tail()
# Out:
#                    High          Low         Open        Close    Volume  \
# Date
# 2020-06-30  1087.689941  1003.729980  1006.500000  1079.810059  16918500
# 2020-07-01  1135.329956  1080.500000  1083.000000  1119.630005  13326900
# 2020-07-02  1228.000000  1185.599976  1221.479980  1208.660034  17250100
# 2020-07-06  1377.790039  1266.040039  1276.689941  1371.579956  20569900
# 2020-07-07  1429.500000  1336.709961  1405.010010  1389.859985  21439900
#
#               Adj Close
# Date
# 2020-06-30  1079.810059
# 2020-07-01  1119.630005
# 2020-07-02  1208.660034
# 2020-07-06  1371.579956
# 2020-07-07  1389.859985

# %%
ford = web.DataReader('F', 'yahoo', start_date, end_date)
gm = web.DataReader('GM', 'yahoo', start_date, end_date)
btc = web.DataReader('BTC-USD', 'yahoo', start_date, end_date)

# %%
ford.tail()
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2020-06-30  6.10  5.90  5.98   6.08  61909300.0       6.08
# 2020-07-01  6.18  5.95  6.10   5.98  62454700.0       5.98
# 2020-07-02  6.17  6.00  6.10   6.05  67270500.0       6.05
# 2020-07-06  6.20  6.11  6.14   6.19  63892900.0       6.19
# 2020-07-07  6.20  6.09  6.14   6.12  55303090.0       6.12

# %%
gm.tail()
btc.tail()
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2020-07-02  9202.344727  9058.794922  9124.842773  9087.303711  1.307897e+10
# 2020-07-03  9183.295898  9053.629883  9084.233398  9132.488281  1.229053e+10
# 2020-07-04  9162.183594  8977.015625  9126.090820  9073.942383  1.290341e+10
# 2020-07-05  9375.474609  9058.664062  9072.849609  9375.474609  1.788926e+10
# 2020-07-08  9293.921875  9251.344727  9258.214844  9293.758789  1.534462e+10
#
#               Adj Close
# Date
# 2020-07-02  9087.303711
# 2020-07-03  9132.488281
# 2020-07-04  9073.942383
# 2020-07-05  9375.474609
# 2020-07-08  9293.758789

# %% [markdown]
# ## Visualize Data for Tesla, Ford & GM
# ### Opening Prices

# %%
tesla['Open'].plot(label='Tesla', figsize=(16,8), title='Opening Prices')
ford['Open'].plot(label='Ford', figsize=(16,8))
gm['Open'].plot(label='GM', figsize=(16,8))
plt.legend();

# %% [markdown]
# ### Daily Trading Volume

# %%
tesla['Volume'].plot(label='Tesla', figsize=(16,8), title='Volume Traded')
ford['Volume'].plot(label='Ford', figsize=(16,8))
gm['Volume'].plot(label='GM', figsize=(16,8))
plt.legend();

# %% [markdown]
# ### Moving Averages for Tesla
# #### MA indicates the closing price

# %%
tesla['MA50'] = tesla['Open'].rolling(50).mean()
tesla['MA200'] = tesla['Open'].rolling(200).mean()
tesla[['Open', 'MA50', 'MA200']].plot(figsize=(16,8));

# %%
### Bitcion
btc['MA50'] = btc['Open'].rolling(50).mean()
btc['MA200'] = btc['Open'].rolling(200).mean()
btc[['Open', 'MA50', 'MA200']].plot(figsize=(16,8));

# %%
### Plotting relationship between the Car Stocks
from pandas.plotting import scatter_matrix

cars = pd.concat([tesla['Open'], ford['Open'], tesla['Open']], axis=1)
cars.columns = ['Tesla Open', 'Ford Open', 'GM Open']
cars.head()
# Out:
#             Tesla Open  Ford Open    GM Open
# Date
# 2012-01-03   28.940001      11.00  28.940001
# 2012-01-04   28.209999      11.15  28.209999
# 2012-01-05   27.760000      11.33  27.760000
# 2012-01-06   27.200001      11.74  27.200001
# 2012-01-09   27.000000      11.83  27.000000

# %%
scatter_matrix(cars, figsize=(8,8), alpha=0.2);

# %% [markdown]
# ### Tesla Candle Stick Chart  For  2020

# %%
import mplfinance as mpf
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

# %%
tesla_reset = tesla.loc['2020-01':].reset_index()
# tesla_reset['date_ax'] = tesla_reset['Date'].apply(lambda date: date2num(date))
list_of_cols = ['Date', 'Open', 'High', 'Low', 'Close']
tesla_values = [tuple(vals) for vals in tesla_reset[list_of_cols].values]

# %%
tesla_df = pd.DataFrame(tesla_values, columns=list_of_cols)
tesla_df.set_index('Date', inplace=True)
mpf.plot(tesla_df,type='candle')
